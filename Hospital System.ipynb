# %%
import re
import random



class hospital():
    
    
    def __init__(self):
        self.__serial_number = 0
        self.__patient_name = ''.capitalize().strip()
        self.__doctor_name = ''.title().strip()
        self.__doc_name = ''.title().strip()
        self.__bill = 0
        self.__payMethod = ''
        self.__credit_card = ''
        self.__diagnosis = ''.capitalize()
        self.__diag = ''.capitalize()
        self.__phone = ''
        self.__email = ''
        self.__report = ''
        self.__day = ''
        self.__temp_day = ''
        self.__time = ''
        self.__temp_time = ''
        self.__diagnosis_menu = ["Dentist", "Dermatologist", "Gastroenterologist", "Psychiatrist", "Hematologist", "Hepatologist", "Orthopedist", "Ent"]
        self.__dentist_doctors = ["Ahmed Roshdy", "Sayed Dawood", "Marwan Mohsen", "Moatez Ezzat"]
        self.__dermatologist_doctors = ["Samy Rashwan", "Ahmed Fawzy", "Mohamed Sayed","Abd El-Rahman Ayman"]
        self.__gastroenterologist_doctors = ["Ramy Tantawy", "Michell George", "Omar Ashraf", "Ahmed Gafaar"]
        self.__psychiatrist_doctors = ["Mohamed Ali", "Youssef Sameh", "Abdallah Tarek", "Mohamed Ahmed"]
        self.__hematologist_doctors = ["Tharwat sabet", "Mohsen Sherif", "Omar Samy", "Osama Sobhy"]
        self.__hepatologist_doctors = ["Amr Hafeez", "Michael Hany", "Peter Medhat", "Ahmed Younes"]
        self.__orthopedist_doctors = ["Saeed Zaki", "Ahmed Saleh", "Fawzy Orabi", "Gafaar Hanfi"]
        self.__ent_doctors = ["Taher Gomaa", "Ahmed Wael", "Yousef Amer", "Sherif Fathi"]
        self.__days = [ "Saturday", "Sunday", "Monday", "Tuesday", "Wednsday"]
        self.__days2 = ["Thursday","Friday"]
        self.__times1 = ["8:00 am", "9:00 am", "10:00 am", "11:00 am", "12:00 pm", "1:00 pm","2:00 pm","3:00 pm","4:00 pm"]
        self.__times2 = ["4:00 pm", "5:00 pm","6:00 pm","7:00 pm","8:00 pm","9:00 pm","10:00 pm","11:00 pm","12:00 pm"]
        self.__paybill = ["70LE", "100LE", "125LE", "250LE", "150LE", "175LE", "150LE", "200LE"]
        self.__payement_methods = ["cash", "credit card"]
        
    def fill_form(self):
        while True:
            name = input("Enter Paitent name: ").title().strip()
            email = input("Email: ")
            print("\nPlease follow that Pattern: 01* **** ****")
            phone = input("Phone number: ")
            checkPhone = re.search("^\d{3}\s\d{4}\s\d{4}$", phone)
            checkEmail = re.search("^[A-z0-9]+@[a-z]+\.(com)$", email)
            if checkPhone:
                self.__phone = phone
            else:
                print("\nWrong phone number try to follow the pattern")
            if checkEmail:
                self.__email = email
            else:
                print("\nwrong Email")
            if checkPhone and checkEmail and name:
                self.__patient_name = name
                self.__serial_number = random.randint(1,100000)
                print("\nForm Applied!!")
                print(f"\nYour serial number is {self.__serial_number}")
                break
            else:
                print("\nError Happens, Please Refill the form")
            
    def __paymentMethod(self):
        while True:
            pay = input("\nChoose a payment Method (cash or credit card): ").lower()
            if pay == self.__payement_methods[0]:
                self.__payMethod = pay
                self.__diagnosis = self.__diag
                self.__doctor_name = self.__doc_name
                self.__day = self.__temp_day
                self.__time = self.__temp_time
                print("\nHonor us at the hospital to pay\n")
                print("\nSuccessfully booked\n")
                break
            elif pay == self.__payement_methods[1]:
                credit = input("\nEnter your credit card number (**** **** **** ****): ")
                check_credit = re.search("^\d{4}\s\d{4}\s\d{4}\s\d{4}$", credit)
                if check_credit:
                    self.__payMethod = pay
                    self.__credit_card = credit
                    self.__diagnosis = self.__diag
                    self.__doctor_name = self.__doc_name
                    self.__day = self.__temp_day
                    self.__time = self.__temp_time
                    print("\nCredit card sumbit!\n")
                    print("\nSuccessfully booked\n")
                    break
                else:
                    print("\nOpreation Failed")
                    print("\nWrong credit card, please try again\n")
            else:
                print("\nOpreation Failed")
                print("\nUnavaliable Payment Method inserted, try again")
            
    def __pay_bill(self):
        if self.__diag == self.__diagnosis_menu[0]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[0]}")
            self.__bill = self.__paybill[0]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[1]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[1]}")
            self.__bill = self.__paybill[1]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[2]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[2]}")
            self.__bill = self.__paybill[2]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[3]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[3]}")
            self.__bill = self.__paybill[3]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[4]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[4]}")
            self.__bill = self.__paybill[4]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[5]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[5]}")
            self.__bill = self.__paybill[5]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[6]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[6]}")
            self.__bill = self.__paybill[6]
            self.__paymentMethod()
        elif self.__diag == self.__diagnosis_menu[7]:
            print(f"\nDetection price for Dr. {self.__doc_name} = {self.__paybill[7]}")
            self.__bill = self.__paybill[7]
            self.__paymentMethod()
        
    
    def __dentist_schedule(self):
        print("\n==========Dentist Schedule==========\n")
        print("Ahmed Roshdy: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Sayed Dawood: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Marwan Mohsen: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Moatez Ezzat: Thursday-Friday (4:00 pm - 12:00 am)")
     
    def __dentist_book(self):
        while True:
            if self.__doc_name == self.__dentist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow this pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__dentist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__dentist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__dentist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
               
    def __dermatologist_schedule(self):
        print("\n==========Dermatologist Schedule==========\n")
        print("Samy Rashwan: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Ahmed Fawzy: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Mohamed Sayed: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Abd el-rahman Ayman: Thursday-Friday (4:00 pm - 12:00 am)")
     
    def __dermatologist_book(self):
        while True:
            if self.__doc_name == self.__dermatologist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow this pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__dermatologist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__dermatologist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__dermatologist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            
                
    def __gastroenterologist_schedule(self):
        print("\n==========Gastroenterologist Schedule==========\n")
        print("Ramy Tantawy: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Michell George: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Omar Ashraf: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Ahmed Gafaar: Thursday-Friday (4:00 pm - 12:00 am)")
     
    def __gastroenterologist_book(self):
        while True:
            if self.__doc_name == self.__gastroenterologist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__gastroenterologist_doctors[1]:
                day = input("\nDay: ").capitalize()
                time = input("Time (Follow that pattern => 12:00 am): ")
                if day in self.__days:
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__gastroenterologist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__gastroenterologist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
    def __psychiatrist_schedule(self):
        print("\n==========Psychiatrist Schedule==========\n")
        print("Mohamed Ali: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Youssef Sameh: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Abdallah Tarek: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Mohamed Ahmed: Thursday-Friday (4:00 pm - 12:00 am)")
    
    def __psychiatrist_book(self):
        while True:
            if self.__doc_name == self.__psychiatrist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__psychiatrist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__psychiatrist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__psychiatrist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
               
                
    def __hematologist_schedule(self):
        print("\n==========Hematologist Schedule==========\n")
        print("Tharwat sabet: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Mohsen Sherif: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Omar Samy: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Osama Sobhy: Thursday-Friday (4:00 pm - 12:00 am)")
    
    def __hematologist_book(self):
        while True:
            if self.__doc_name == self.__hematologist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__hematologist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__hematologist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__hematologist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                

    def __hepatologist_schedule(self):
        print("\n==========Hematologist Schedule==========\n")
        print("Amr Hafeez: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Michael Hany: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Peter Medhat: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Ahmed Younes: Thursday-Friday (4:00 pm - 12:00 am)")
    
    def __hepatologist_book(self):
        while True:
            if self.__doc_name == self.__hepatologist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__hepatologist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__hepatologist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doctor_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__hepatologist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}, try again")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}")
                

                
    def __orthopedist_schedule(self):
        print("\n==========Orthopedist Schedule==========\n")
        print("Saeed Zaki: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Ahmed Saleh: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Fawzy Orabi: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Gafaar Hanfi: Thursday-Friday (4:00 pm - 12:00 am)")
    
    def __orthopedist_book(self):
        while True:
            if self.__doc_name == self.__orthopedist_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__orthopedist_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__orthopedist_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__orthopedist_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
    
    def __ent_schedule(self):
        print("\n==========ENT Schedule==========\n")
        print("Taher Gomaa: Saturday-Wednsday (8:00 am - 4:00 pm)")
        print("Ahmed Wael: Saturday-Wednsday (4:00 pm - 12:00 am)")
        print("Yousef Amer: Thursday-Friday (8:00 am - 4:00 pm)")
        print("Sherif Fathi: Thursday-Friday (4:00 pm - 12:00 am)")
    
    def __ent_book(self):
        while True:
            if self.__doc_name == self.__ent_doctors[0]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
                
            elif self.__doc_name == self.__ent_doctors[1]:
                day = input("\nDay: ").capitalize()
                if day in self.__days:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__ent_doctors[2]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times1:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
            elif self.__doc_name == self.__ent_doctors[3]:
                day = input("\nDay: ").capitalize()
                if day in self.__days2:
                    time = input("Time (Follow that pattern => 12:00 am): ")
                    if time in self.__times2:
                        print("\nDay and time sumbitted!")
                        self.__temp_day = day
                        self.__temp_time = time
                        self.__pay_bill()
                        break
                    else:
                        print(f"Make sure that you have inserted suited time for Dr. {self.__doc_name}")
                else:
                    print(f"Dr. {self.__doc_name} not avaliable on {day}, try again")
    
    
    def __doctors(self):
        while True:
            if self.__diag == self.__diagnosis_menu[0]:
                print("\n=========Dentist Doctors=========\n")
                for doc in self.__dentist_doctors:
                    print(f"Dr. {doc}")
                self.__dentist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__dentist_doctors:
                    print(f"\nBooked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__dentist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[1]:
                print("\n=========Dermatologist Doctors=========\n")
                for doc in self.__dermatologist_doctors:
                    print(f"Dr. {doc}")
                self.__dermatologist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__dermatologist_doctors:
                    print(f"\nBooked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__dermatologist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[2]:
                print("\n=========Gastroenterologist Doctors=========\n")
                for doc in self.__gastroenterologist_doctors:
                    print(f"Dr. {doc}")
                self.__gastroenterologist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__gastroenterologist_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__gastroenterologist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[3]:
                print("\n=========Psychiatrist Doctors=========\n")
                for doc in self.__psychiatrist_doctors:
                    print(f"Dr. {doc}")
                self.__psychiatrist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__psychiatrist_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__psychiatrist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[4]:
                print("\n=========Hematologist Doctors=========\n")
                for doc in self.__hematologist_doctors:
                    print(f"Dr. {doc}")
                self.__hematologist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__hematologist_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__hematologist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[5]:
                print("\n=========Hepatologist Doctors=========\n")
                for doc in self.__hepatologist_doctors:
                    print(f"Dr. {doc}")
                self.__hepatologist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__hepatologist_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__hepatologist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[6]:
                print("\n=========Orthopedist Doctors=========\n")
                for doc in self.__orthopedist_doctors:
                    print(f"Dr. {doc}")
                self.__orthopedist_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__orthopedist_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__orthopedist_book()
                    break
                else:
                    print(f"Choose from the list please")
                
            elif self.__diag == self.__diagnosis_menu[7]:
                print("\n=========ENT Doctors=========\n")
                for doc in self.__ent_doctors:
                    print(f"Dr. {doc}")
                self.__ent_schedule()
                doctor = input("\nChoose a Doctor: ").title().strip()
                if doctor in self.__ent_doctors:
                    print(f"Booked for Dr {doctor}")
                    print(f"\nNow Select Day and Time\n for Dr. {doctor}")
                    self.__doc_name = doctor
                    self.__ent_book()
                    break
                else:
                    print(f"Choose from the list please")
            else:
                print("No Doctors for this expertise")
            
            
    def diagnosis(self):
        while True:
            print("\nOur Specilest:\n")
            for dia in self.__diagnosis_menu:
                print(f"- {dia}")
            diagnos = input("\nChoose an Expertise: ").capitalize()
            if diagnos in self.__diagnosis_menu:
                report = input("\nType description of What are you suffering from: ")
                self.__report = report
                self.__diag = diagnos
                print("\nReport Promoted Successfully!\n")
                self.__doctors()
                break
            else:
                print("\nUnavaliable Expertise, Try Again\n")
            
    def data_modification(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            patient_name = input("Modfiy Patient name: ")
            email = input("\nModify Email: ")
            print("\nPlease follow that Pattern: 01* **** ****")
            phone = input("\nModify Phone number: ")
            checkPhone = re.search("^\d{3}\s\d{4}\s\d{4}$", phone)
            checkEmail = re.search("^[A-z0-9]+@[a-z]+\.(com)$", email)
            if checkEmail and checkPhone:
                self.__patient_name = patient_name
                self.__email = email
                self.__phone = phone
                self.__paymentMethod()
                print("\nData modified Successfully!!")
            else:
                print("\nOpreation Failed")
                print("\nPhone or email are wrong Please make sure to insert a valid one")
        else:
            print("\nOpreation Failed")
            print("\nWrong Serial Number")
            
    def modify_patien_name(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            serial.__patient_name = input("\nModify Patient Name: ")
            print("Patien Name Updated Successfully!!")
        else:
            print("\nOpreation Failed")
            print("\nWrong Serial Number")
            
    def modify_email(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            email = input("\nModify Email: ")
            checkEmail = re.search("^[A-z0-9]+@[a-z]+\.(com)$", email)
            if checkEmail:
                self.__email = email
                print("\n Email Updated Successfully!")
            else:
                print("\nOpreation Falied")
                print("\nEmail doseen't exist")
        else:
            print("\nOpreation Failed")
            print("\nWrong Serial Number")
            
    def modify_phone(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            print("\nPlease follow that Pattern: 01* **** ****")
            phone = input("Phone number: ")
            checkPhone = re.search("^\d{3}\s\d{4}\s\d{4}$", phone)
            if checkPhone:
                self.__phone = phone
                print("\nPhone Number Updated Successfully!!")
            else:
                print("\nOpreation Falied!!")
                print("\nPhone number dosen't Exist")
                
    def modify_booked_doctor(self):
        print(f"\nyou choose {self.__diagnosis}")
        print(f"\nyour Previous doctor is Dr. {self.__doctor_name}")
        self.__doctors()
        
    def modify_diagnose(self):
        print(f"\n your diagnosis is {self.__diagnosis}")
        self.diagnosis()
            
    def modify_payment_method(self):
        self.__paymentMethod()
        
    def get_data(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            print(f"\nPatient Name : {self.__patient_name}")
            print(f"Patient Email: {self.__email}")
            print(f"Patient Phone Number: {self.__phone}")
            print(f"Patient Diagnose : {self.__diagnosis}")
            print(f"Patient booked with Doctor: {self.__doctor_name}")
            print(f"Examination date on {self.__day} at {self.__time}")
            print(f"Examination Price: {self.__bill}")
            print(f"Payment Method: {self.__payMethod}")
            
        else:
            print("\nOpreation Failed")
            print("Wrong Serial Number")
            
    def get_name(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"\nPatient Name: {self.__patient_name}"
        else:
            print("\nWrong Serial Number")
    
    def get_email(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"\nEmail: {self.__email}"
        else:
            print("\nWrong Serial Number")
    
    def get_phone(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"Phone: {self.__phone}"
        else:
            print("\nWrong Serial Number")
    
    def get_booked_doctor(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"Booked with Dr. {self.__doctor_name}"
        else:
            print("\nWrong Serial Number")
    
    def get_diagnosis(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"Diagnosis: {self.__diagnosis}"
        else:
            print("\nWrong Serial Number")
    
    def get_detection_price(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"Detection Price: {self.__bill}"
        else:
            print("\nWrong Serial Number")
    
    def get_payment_method(self):
        try:
            serial = int(input("\nWrite your serial number: "))
        except ValueError:
            print("\nSerial number contain integers only")
        if serial == self.__serial_number:
            return f"Payment Method: {self.__payMethod}"
        else:
            print("\nWrong Serial Number")

# %%
patient = hospital()

# %%
def intro():
    print("\t\t\t************************************************************")
    print("\t\t\t========== WELCOME TO My HOSPITAL SYSTEM ==========")
    print("\t\t\t************************************************************")
    
def main_menu():
    print("\n************************************************************")
    print("========== Hospital Menu ==========")
    print("************************************************************\n")
    print("========== (1). Modify Data ============")
    print("========== (2). Modifiy Booked doctor ============")
    print("========== (3). Modify diagnose ============")
    print("========== (4). Get my data ============")
    print("========== (5). Get my Sheet ============")
    print("========== (6). Exit ============")
    print("************************************************************\n")
    
def modify_menu():
    print("\n========== (1). Modify All Data ============")
    print("========== (2). Modify Patient Name ============")
    print("========== (3). Modify email ============")
    print("========== (4). Modify phone ============")
    print("========== (5). Modify Payment Method ============")
    print("========== (6). Exit ============")
    print("************************************************************")
    
def get_menu():
    print("\n========== (1). Get patient name ============")
    print("========== (2). Get email ============")
    print("========== (3). Get Phone number ============")
    print("========== (4). Get diagnosis ============")
    print("========== (5). Get booked doctor ============")
    print("========== (6). Get Examination Price ============")
    print("========== (7). Get Payment Method ============")
    print("========== (8). Exit ============")
    print("************************************************************")

def filling_form():
    patient.fill_form()
    
def diagnose():
    patient.diagnosis()
    
def modify_data():
    modify_menu()
    ch = input("\nChoose an Option: ")
    while ch != '6':
        if ch == '1':
            patient.data_modification()
        elif ch == '2':
            patient.modify_patien_name()
        elif ch == '3':
            patient.modify_email()
        elif ch == '4':
            patient.modify_phone()
        elif ch == '5':
            patient.modify_payment_method()
        else:
            print("\nWrong Option Inserted Please Try again")
        modify_menu()
        ch = input("\nChoose an Option: ")
            
def modify_booked_doc():
    patient.modify_booked_doctor()
    
def modify_dig():
    patient.modify_diagnose()
    
def get_my_data():
    get_menu()
    ch = input("\nChoose an Option: ")
    while ch != '8':
        if ch == '1':
            print(patient.get_name())
        elif ch == '2':
            print(patient.get_email())
        elif ch == '3':
            print(patient.get_phone())
        elif ch == '4':
            print(patient.get_diagnosis())
        elif ch == '5':
            print(patient.get_booked_doctor())
        elif ch == '6':
            print(patient.get_detection_price())
        elif ch == '7':
            print(patient.get_payment_method())
        else:
            print("\nWrong Option Inserted Please Try again")
        get_menu()
        ch = input("\nChoose an Option: ")
        
def get_my_sheet():
    patient.get_data()

# %%
intro()

print("\nFill The Form Please\n")
filling_form()
diagnose()
main_menu()
ch = input("Choose an Option: ")
while ch != '6':
    if ch == '1':
        modify_data()
        input("Press any Key to return to hospital menu")
    elif ch == '2':
        modify_booked_doc()
        input("Press any Key to return to hospital menu")
    elif ch == '3':
        modify_dig()
        input("Press any Key to return to hospital menu")
    elif ch == '4':
        get_my_data()
        input("Press any Key to return to hospital menu")
    elif ch == '5':
        get_my_sheet()
        input("Press any Key to return to hospital menu")
    else:
        print("\nWrong Option Please try again\n")
    main_menu()
    ch = input("Choose an Option: ")
# Out:
# 			************************************************************
# 			========== WELCOME TO My HOSPITAL SYSTEM ==========
# 			************************************************************
#
# Fill The Form Please
#
# Enter Paitent name: eyad ayman
# Email: eyadaiman@outlook.com
#
# Please follow that Pattern: 01* **** ****
# Phone number: 010 9987 3772
#
# Form Applied!!
#
# Your serial number is 91651
#
# Our Specilest:
#
# - Dentist
# - Dermatologist
# - Gastroenterologist
# - Psychiatrist
# - Hematologist
# - Hepatologist
# - Orthopedist
# - Ent
#
# Choose an Expertise: ent
#
# Type description of What are you suffering from: my ears
#
# Report Promoted Successfully!
#
#
# =========ENT Doctors=========
#
# Dr. Taher Gomaa
# Dr. Ahmed Wael
# Dr. Yousef Amer
# Dr. Sherif Fathi
#
# ==========ENT Schedule==========
#
# Taher Gomaa: Saturday-Wednsday (8:00 am - 4:00 pm)
# Ahmed Wael: Saturday-Wednsday (4:00 pm - 12:00 am)
# Yousef Amer: Thursday-Friday (8:00 am - 4:00 pm)
# ...
